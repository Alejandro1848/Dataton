# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df=pd.read_csv("C:/Users/I_am_AlexX/Downloads/Covid-19_SINAVE_Ciudad_de_México/sisver_public.csv")

# %%
df.head()
# Out:
#           origen sector  cveentuni           entidad            delega                             unidad               fechreg       sexo           entresi  cventine    mpioresi  cvemuni                locresi  cvelocal     tipacien                evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind     ocupacio          seringre              fecingre              fecinisi                                   diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo conanima vacunado              fecvaest tommue                                   labora  follabor    resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3 
# ...

# %%
df.columns.values
# Out:
# array(['origen', 'sector', 'cveentuni', 'entidad', 'delega', 'unidad',
#        'fechreg', 'sexo', 'entresi', 'cventine', 'mpioresi', 'cvemuni',
#        'locresi', 'cvelocal', 'tipacien', 'evoluci', 'fecdef', 'semdef',
#        'intubado', 'digcline', 'edad', 'naciona', 'estaemba', 'mesesemb',
#        'esindige', 'hableind', 'ocupacio', 'seringre', 'fecingre',
#        'fecinisi', 'diagprob', 'fiebre', 'tos', 'odinogia', 'disnea',
#        'irritabi', 'diarrea', 'dotoraci', 'calofrios', 'cefalea',
#        'mialgias', 'artral', 'ataedoge', 'rinorrea', 'polipnea', 'vomito',
#        'dolabdo', 'conjun', 'cianosis', 'inisubis', 'diabetes', 'epoc',
#        'asma', 'inmusupr', 'hiperten', 'vih_sida', 'otracon', 'enfcardi',
#        'obesidad', 'insrencr', 'tabaquis', 'rectrata', 'txcrobia',
#        'txantivi', 'antivira', 'fecinitxantivi', 'conocaso', 'contaves',
#        'concerdo', 'conanima', 'vacunado', 'fecvaest', 'tommue', 'labora',
# ...

# %%
df.shape
# Out:
# (4018447, 92)

# %%
df.entidad.unique()
# Out:
# array(['CIUDAD DE MEXICO', 'MORELOS', 'HIDALGO', 'OAXACA', 'MEXICO',
#        'PUEBLA', 'VERACRUZ', 'MICHOACAN', 'GUANAJUATO', 'CAMPECHE',
#        'GUERRERO', 'TABASCO', 'JALISCO', 'CHIAPAS', 'SAN LUIS POTOSI',
#        'SINALOA', 'BAJA CALIFORNIA', 'ZACATECAS', 'COAHUILA',
#        'BAJA CALIFORNIA SUR', 'QUERETARO', 'COLIMA', 'YUCATAN', 'SONORA',
#        'TLAXCALA', 'AGUASCALIENTES', 'NAYARIT', 'DURANGO', 'QUINTANA ROO',
#        'NUEVO LEON', 'CHIHUAHUA', 'TAMAULIPAS'], dtype=object)

# %%
#casos_CDMX_ago_sep.mpioresi.unique()

# %% [markdown]
# ## Primer Fitro- Casos en CDMX

# %%
in_CDMX = df['entidad'] == "CIUDAD DE MEXICO"

# %%
casos_CDMX = df[in_CDMX]

# %%
casos_CDMX.head(2)
# Out:
#           origen sector  cveentuni           entidad            delega                    unidad               fechreg       sexo           entresi  cventine mpioresi  cvemuni  locresi  cvelocal     tipacien                evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind     ocupacio          seringre              fecingre              fecinisi                                   diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo conanima vacunado fecvaest tommue                                   labora  follabor    resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  viaje4  viaje5 antigencovid  \
# ...

# %%
casos_CDMX.shape
# Out:
# (3992809, 92)

# %%
sns.set_theme(style="ticks", color_codes=True)

# %%
casos_CDMX.shape
# Out:
# (3992809, 92)

# %% [markdown]
# ## Segundo Fitro- Casos en cierto intervalo de fechas

# %% [markdown]
# ### Junio 30 a mayo 30 de 2021

# %%
fecha_inicial = '2021-06-30T00:00:00Z'
fecha_final = '2021-09-30T00:00:00Z'

# %%
# Según el diccionario del data-set "fecinisi" Indica la Fecha en que el paciente comenzó con síntomas

jun_30_a_sep_30 = (casos_CDMX["fecinisi"] > fecha_inicial) & (casos_CDMX["fecinisi"] <= fecha_final)

# %%
casos_CDMX_jun_sep = casos_CDMX.loc[jun_30_a_sep_30]
casos_CDMX_jun_sep.head(2)
# Out:
#           origen sector  cveentuni           entidad            delega           unidad               fechreg       sexo           entresi  cventine  mpioresi  cvemuni   locresi  cvelocal     tipacien                evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind   ocupacio          seringre              fecingre              fecinisi                                   diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo conanima vacunado fecvaest tommue labora  follabor  resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  viaje4  viaje5 antigencovid   fecha_actualizacion
# ...

# %%
casos_CDMX_jun_sep.shape
# Out:
# (970036, 92)

# %%
#casos_CDMX["fecinisi"][:5]

# %%
#casos_CDMX[:100]

# %% [markdown]
# ### Agosto 30 a septiembre 30 de 2021

# %%
fecha_inicial_a = '2021-08-30T00:00:00Z'
fecha_final_s = '2021-09-30T00:00:00Z'

# %%
# Según el diccionario del data-set "fecinisi" Indica la Fecha en que el paciente comenzó con síntomas

ago_30_a_sep_30 = (casos_CDMX["fecinisi"] > fecha_inicial_a) & (casos_CDMX["fecinisi"] <= fecha_final_s)

# %%
casos_CDMX_ago_sep = casos_CDMX.loc[ago_30_a_sep_30]
casos_CDMX_ago_sep.head()
# Out:
#             origen sector  cveentuni           entidad            delega                               unidad               fechreg       sexo           entresi  cventine    mpioresi  cvemuni               locresi  cvelocal     tipacien                   evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind     ocupacio          seringre              fecingre              fecinisi                                   diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo conanima vacunado fecvaest tommue labora  follabor    resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  viaje4  viaje5 antigencovid  \
# ...

# %%
casos_CDMX_ago_sep.shape
# Out:
# (125127, 92)

# %%
sns.catplot(x="resdefin", y="edad", hue="sexo", aspect=2,kind="swarm", data=casos_CDMX_ago_sep[0:900])

# %%
sns.set(rc={'figure.figsize':(14.7,11.27)})
sns.stripplot(x="resdefin", y="edad", hue="sexo", data=casos_CDMX_ago_sep[0:10000])
# Out:
# <AxesSubplot:xlabel='resdefin', ylabel='edad'>

# %%
#sns.stripplot(x="edad", y="resdefin", hue="sexo", data=casos_CDMX_ago_sep[0:10000])

# %%
sns.set(rc={'figure.figsize':(14.7,11.27)}) #tamaño del gráfico

# %%
sns.set(font_scale = 1)

# %%
casos_CDMX_ago_sep.shape #shape
# Out:
# (125127, 92)

# %%
plt.xticks(rotation=90)
casos_por_del=sns.countplot(x='mpioresi',data=casos_CDMX_ago_sep[0:21500])
casos_por_del.set(xlabel='delegación', ylabel='número de pacientes')
# Out:
# [Text(0.5, 0, 'delegación'), Text(0, 0.5, 'número de pacientes')]

# %% [markdown]
# ## Tercer Fitro- Casos solo en alguna de las 16 alcaldías de la CDMX.

# %% [markdown]
# Observando la anterior gráfica podemos ver que por cómo está construida la base de datos, pese a que hemos
# hecho ya un filtro previo de solo tomar en cuenta aquellos casos de la Ciudad de México, siguen apareciendo municipios
# correspondientes a otros estados, por lo que será necesario hacer nuevamente otro filtro de datos, pero ahora
# tomando solo en cuenta aquellos "municipios" que correspondan a los nombres de las alcaldías de la Ciudad de México
# como se mostrará a continuación.
# Recuérdese que la columna que tiene está información es "mpioresi"
#
# Según el diccionario de datos "mpioresi":
#
# Indica el municipio de residencia del paciente

# %%
solo_delegaciones = (casos_CDMX_ago_sep["mpioresi"] == "IZTAPALAPA") | (casos_CDMX_ago_sep["mpioresi"] == "MILPA ALTA") | (casos_CDMX_ago_sep["mpioresi"] == "XOCHIMILCO") | (casos_CDMX_ago_sep["mpioresi"] == "TLALPAN") |(casos_CDMX_ago_sep["mpioresi"] == "COYOACAN") | (casos_CDMX_ago_sep["mpioresi"] == "CUAJIMALPA DE MORELOS") |(casos_CDMX_ago_sep["mpioresi"] == "AZCAPOTZALCO") | (casos_CDMX_ago_sep["mpioresi"] == "ALVARO OBREGON") |(casos_CDMX_ago_sep["mpioresi"] == "TLAHUAC") | (casos_CDMX_ago_sep["mpioresi"] == "GUSTAVO A. MADERO") |(casos_CDMX_ago_sep["mpioresi"] == "MIGUEL HIDALGO") | (casos_CDMX_ago_sep["mpioresi"] == "IZTACALCO") |(casos_CDMX_ago_sep["mpioresi"] == "CUAUHTEMOC") | (casos_CDMX_ago_sep["mpioresi"] == "VENUSTIANO CARRANZA") |(casos_CDMX_ago_sep["mpioresi"] == "BENITO JUAREZ") | (casos_CDMX_ago_sep["mpioresi"] == "LA MAGDALENA CONTRERAS")

# %% [markdown]
# Creamos un nuevo data set que solo contenga información de las 16 alcaldías de la Ciudad de México.

# %%
casos_CDMX_ago_sep_solo_del = casos_CDMX_ago_sep.loc[solo_delegaciones]
casos_CDMX_ago_sep_solo_del.head(2)
# Out:
#            origen sector  cveentuni           entidad            delega                             unidad               fechreg      sexo           entresi  cventine    mpioresi  cvemuni     locresi  cvelocal     tipacien                evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind     ocupacio          seringre              fecingre              fecinisi                         diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo conanima vacunado fecvaest tommue labora  follabor    resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  viaje4  viaje5 antigencovid   fecha_actualizacion
# ...

# %% [markdown]
# Una forma sencilla de ver la cantidad total de pecientes registrados del 30/08/2021 al 30/09/2021 es viendo las dimensiones del data set:

# %%
casos_CDMX_ago_sep_solo_del.shape #shape
# Out:
# (108655, 92)

# %% [markdown]
# Obervándose un total de 108655 pacientes en la Ciudad de México

# %%
#casos_CDMX_ago_sep.mpioresi.unique()

# %%
#casos_CDMX_ago_sep_solo_del.mpioresi.unique()

# %%
plt.xticks(rotation=90)
casos_por_del=sns.countplot(x='mpioresi',data=casos_CDMX_ago_sep_solo_del)
casos_por_del.set(xlabel='delegación', ylabel='número de pacientes')
# Out:
# [Text(0.5, 0, 'delegación'), Text(0, 0.5, 'número de pacientes')]

# %% [markdown]
# La gráfica anterior, ya corregida, tiene la forma esperada con la información del número total de pacientes por cada una de las 16 alcaldías de la Ciudad de México.

# %% [markdown]
# Una primera información relevante, dentro de este análisis exploratorio, y que sería de interés para el gobierno, ya iniciada la jornada de vacunación meses atrás, sería ver cuántos casos positivos de covid-19 hay en este sector de la población y contrastarla con el número de vacunados y no vacunados dentro del mismo.

# %% [markdown]
# Dentro del diccionario de datos existe el campo "RESDEFIN" el cual indica: el resultado definitivo de la muestra de laboratorio específicamente este estudio puede arrojar los siguientes resultados
#
# AH3; B; CORONA HKU1; CORONA HNL63; ENTEROV//RHINOVIRUS; INF 1; INF AH1N1 PMD; NEGATIVO; NO ADECUADO; NO RECIBIDA; NO SUBTIPIFICADO; PARAINFLUENZA 1; PARAINFLUENZA 2; RECHAZADA; SARS-CoV-2; VSR

# %% [markdown]
# Para nuestro caso veremos la proporción que hay sobre estos resultados en la Ciudad de México:

# %%
sns.stripplot(x="resdefin",y="edad",data=casos_CDMX_ago_sep_solo_del)
# Out:
# <AxesSubplot:xlabel='resdefin', ylabel='edad'>

# %% [markdown]
# Una vez vista la proporción podemos ver ahora cómo es la distribución de pacientes según el resultado del laboratorio.

# %%
plt.xticks(rotation=90)
casos_por_del=sns.countplot(x='resdefin',data=casos_CDMX_ago_sep_solo_del)
casos_por_del.set(xlabel='delegación', ylabel='número de pacientes')
# Out:
# [Text(0.5, 0, 'delegación'), Text(0, 0.5, 'número de pacientes')]

# %% [markdown]
# Sería interesante ahora ver cómo se ha comportado la cantidad de casos positivos de covid-19 y compararla con datos de principio de la pandemia, en ella debería haber un contraste muy marcado sobre todo en el número de fallecimientos, pues la jornada de vacunación ya lleva una considerable cantidad de tiempo en práctica y por tanto debería ser posible corroborar la efectividad que tiene el vacunar a la gente y así evitar más contagios y menos fallecimientos.

# %% [markdown]
# Para ello será necesario primero, cambiar el formato original de la columna "fechreg" a uno por el que podamos cambiar su formato y así poder ordenar los datos por fecha, pues en el formato que se encuentra es imposible hacerlo.

# %%
casos_CDMX_ago_sep_solo_del.head(1)
# Out:
#            origen sector  cveentuni           entidad            delega                             unidad               fechreg      sexo           entresi  cventine    mpioresi  cvemuni     locresi  cvelocal     tipacien                evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind ocupacio          seringre              fecingre              fecinisi                         diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo conanima vacunado fecvaest tommue labora  follabor  resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  viaje4  viaje5 antigencovid   fecha_actualizacion
# ...

# %% [markdown]
# Primero cambiamos el formato:

# %%
casos_CDMX_ago_sep_solo_del["fecinisi"] = df["fecinisi"].replace({'T00:00:00Z':''}, regex=True)
# Out:
# <ipython-input-19-d70fc09cba1e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   casos_CDMX_ago_sep_solo_del["fecinisi"] = df["fecinisi"].replace({'T00:00:00Z':''}, regex=True)

# %%
casos_CDMX_ago_sep_solo_del.head(1)
# Out:
#            origen sector  cveentuni           entidad            delega                             unidad               fechreg      sexo           entresi  cventine    mpioresi  cvemuni     locresi  cvelocal     tipacien                evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind ocupacio          seringre              fecingre    fecinisi                         diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo conanima vacunado fecvaest tommue labora  follabor  resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  viaje4  viaje5 antigencovid   fecha_actualizacion
# ...

# %%
#casos_CDMX_ago_sep_solo_del.dtypes

# %% [markdown]
# Ahora cambiamos el tipo de dato de los valores originales de "fechreg" por el tipo de dato llamado "date_time"

# %%
casos_CDMX_ago_sep_solo_del["fecinisi"]=pd.to_datetime(casos_CDMX_ago_sep_solo_del["fecinisi"])
# Out:
# <ipython-input-44-c8302e1ad613>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   casos_CDMX_ago_sep_solo_del["fecinisi"]=pd.to_datetime(casos_CDMX_ago_sep_solo_del["fecinisi"])

# %%
casos_CDMX_ago_sep_solo_del.head(1)
# Out:
#            origen sector  cveentuni           entidad            delega                             unidad               fechreg      sexo           entresi  cventine    mpioresi  cvemuni     locresi  cvelocal     tipacien                evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind ocupacio          seringre              fecingre   fecinisi                         diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo conanima vacunado fecvaest tommue labora  follabor  resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  viaje4  viaje5 antigencovid   fecha_actualizacion
# ...

# %% [markdown]
# ## Nuevo data set ordenado por fecha

# %%
casos_CDMX_ago_sep_solo_del_sort=casos_CDMX_ago_sep_solo_del.sort_values(["fecinisi"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ca9630a4a47f> in <module>
# ----> 1 casos_CDMX_ago_sep_solo_del_sort=casos_CDMX_ago_sep_solo_del.sort_values(["fecinisi"])
#
# NameError: name 'casos_CDMX_ago_sep_solo_del' is not defined

# %%
casos_CDMX_ago_sep_solo_del_sort.shape

# %%
casos_CDMX_ago_sep_solo_del_sort.head(5)
# Out:
#                 origen   sector  cveentuni           entidad            delega                                    unidad               fechreg       sexo           entresi  cventine           mpioresi  cvemuni            locresi  cvelocal     tipacien                   evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind                                     ocupacio          seringre              fecingre   fecinisi                         diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo        conanima vacunado              fecvaest tommue labora  follabor    resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  \
# ...

# %%
sns.catplot(x="resdefin", y="fecinisi", hue="resdefin", aspect=2,kind="swarm", data=casos_CDMX_ago_sep_solo_del[0:100])

# %% [markdown]
# Vemos que los filtros que hemos hecho funcionan correctamente, ahora haremos un nuevo filtro pues sólo estamos interesados en aquellas personas que dieron positivo a SARS-CoV-2, y luego haremos otro nuevo filtro para ver cuántas de esas personas fallecieron.

# %% [markdown]
# # Nuevo data set con solo los casos positivos de 30 de agosto a 30 de septiembre

# %%
resdefin_SARS_CoV_2 = casos_CDMX_ago_sep_solo_del_sort['resdefin'] == "SARS-CoV-2"

# %%
casos_CDMX_ago_sep_positivos_CoV_19 = casos_CDMX_ago_sep_solo_del_sort[resdefin_SARS_CoV_2]

# %%
casos_CDMX_ago_sep_positivos_CoV_19.shape
# Out:
# (17918, 92)

# %%
casos_CDMX_ago_sep_positivos_CoV_19.head(1)
# Out:
#                 origen sector  cveentuni           entidad            delega           unidad               fechreg      sexo           entresi  cventine  mpioresi  cvemuni   locresi  cvelocal     tipacien         evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind   ocupacio          seringre              fecingre   fecinisi                         diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo conanima vacunado fecvaest tommue labora  follabor    resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  viaje4  viaje5 antigencovid   fecha_actualizacion
# ...

# %%
casos_p_2 =  casos_CDMX_ago_sep_positivos_CoV_19.groupby(["fecinisi","resdefin"]).size()
casos_p_2
# Out:
# fecinisi    resdefin
# 2021-08-31  SARS-CoV-2    1448
# 2021-09-01  SARS-CoV-2    1779
# 2021-09-02  SARS-CoV-2    1362
# 2021-09-03  SARS-CoV-2    1378
# 2021-09-04  SARS-CoV-2    1080
# 2021-09-05  SARS-CoV-2    1084
# 2021-09-06  SARS-CoV-2    1405
# 2021-09-07  SARS-CoV-2    1188
# 2021-09-08  SARS-CoV-2    1068
# 2021-09-09  SARS-CoV-2     994
# 2021-09-10  SARS-CoV-2    1082
# 2021-09-11  SARS-CoV-2     872
# 2021-09-12  SARS-CoV-2     616
# 2021-09-13  SARS-CoV-2     777
# 2021-09-14  SARS-CoV-2     655
# 2021-09-15  SARS-CoV-2     507
# 2021-09-16  SARS-CoV-2     218
# 2021-09-17  SARS-CoV-2     270
# 2021-09-18  SARS-CoV-2     110
# 2021-09-19  SARS-CoV-2      24
# 2021-09-20  SARS-CoV-2       1
# dtype: int64

# %%
casos_p_2.plot(xlabel='fecinisi')
# Out:
# <AxesSubplot:xlabel='fecinisi'>

# %% [markdown]
#  # Filtro de fechas del 1 de Marzo de 2020 al 2 de julio de 2021

# %% [markdown]
# Vamos ahora a analizar el  periodo de tiempo que abarca el data set de la afluencia total en el STC metro de la CDMX.

# %%
del df

# %%
casos_CDMX.head(1)
# Out:
#           origen sector  cveentuni           entidad            delega                    unidad               fechreg      sexo           entresi  cventine mpioresi  cvemuni  locresi  cvelocal     tipacien                evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind     ocupacio          seringre              fecingre              fecinisi                                   diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo conanima vacunado fecvaest tommue                                   labora  follabor    resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  viaje4  viaje5 antigencovid  \
# ...

# %%
fecha_inicial = '2020-03-01T00:00:00Z'
fecha_final = '2021-07-02T00:00:00Z'

# Según el diccionario del data-set "fecinisi" Indica la Fecha en que el paciente comenzó con síntomas

mar_2020_a_jul_2021 = (casos_CDMX["fecinisi"] > fecha_inicial) & (casos_CDMX["fecinisi"] <= fecha_final)

casos_CDMX_mar_jul_20_21 = casos_CDMX.loc[mar_2020_a_jul_2021]
casos_CDMX_mar_jul_20_21.head(2)
# Out:
#           origen sector  cveentuni           entidad            delega                          unidad               fechreg      sexo           entresi  cventine    mpioresi  cvemuni                locresi  cvelocal     tipacien                evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind     ocupacio          seringre              fecingre              fecinisi                                   diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo conanima vacunado              fecvaest tommue                                   labora  follabor    resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  \
# ...

# %%
del df # usamos del df para borrar el data set cargado en la memoria RAM pues ahora solo vamos a trabajar con el data set de abajo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ab11d9cd4e5c> in <module>
# ----> 1 del df # usamos del df para borrar el data set cargado en la memoria RAM pues ahora solo vamos a trabajar con el data set de abajo
#
# NameError: name 'df' is not defined

# %%
del casos_CDMX # incluso podemos borrar el data set casos_CDMX para optimizar aún más la memoria RAM del computador.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-36466bb1da93> in <module>
# ----> 1 del casos_CDMX # incluso podemos borrar el data set casos_CDMX para optimizar aún más la memoria RAM del computador.
#
# NameError: name 'casos_CDMX' is not defined

# %%
casos_CDMX_mar_jul_20_21.tail(1)
# Out:
#                 origen sector  cveentuni           entidad            delega                                   unidad               fechreg       sexo           entresi  cventine    mpioresi  cvemuni     locresi  cvelocal     tipacien                evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind  ocupacio          seringre              fecingre              fecinisi                         diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo conanima vacunado fecvaest tommue labora  follabor  resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  viaje4  viaje5 antigencovid   fecha_actualizacion
# ...

# %%
solo_delegaciones = (casos_CDMX_mar_jul_20_21["mpioresi"] == "IZTAPALAPA") | (casos_CDMX_mar_jul_20_21["mpioresi"] == "MILPA ALTA") | (casos_CDMX_mar_jul_20_21["mpioresi"] == "XOCHIMILCO") | (casos_CDMX_mar_jul_20_21["mpioresi"] == "TLALPAN") |(casos_CDMX_mar_jul_20_21["mpioresi"] == "COYOACAN") | (casos_CDMX_mar_jul_20_21["mpioresi"] == "CUAJIMALPA DE MORELOS") |(casos_CDMX_mar_jul_20_21["mpioresi"] == "AZCAPOTZALCO") | (casos_CDMX_mar_jul_20_21["mpioresi"] == "ALVARO OBREGON") |(casos_CDMX_mar_jul_20_21["mpioresi"] == "TLAHUAC") | (casos_CDMX_mar_jul_20_21["mpioresi"] == "GUSTAVO A. MADERO") |(casos_CDMX_mar_jul_20_21["mpioresi"] == "MIGUEL HIDALGO") | (casos_CDMX_mar_jul_20_21["mpioresi"] == "IZTACALCO") |(casos_CDMX_mar_jul_20_21["mpioresi"] == "CUAUHTEMOC") | (casos_CDMX_mar_jul_20_21["mpioresi"] == "VENUSTIANO CARRANZA") |(casos_CDMX_mar_jul_20_21["mpioresi"] == "BENITO JUAREZ") | (casos_CDMX_mar_jul_20_21["mpioresi"] == "LA MAGDALENA CONTRERAS")

# %%
casos_CDMX_mar_jul_20_21_solo_del = casos_CDMX_mar_jul_20_21.loc[solo_delegaciones]

# %%
del casos_CDMX_mar_jul_20_21

# %%
casos_CDMX_mar_jul_20_21_solo_del.head(1)
# Out:
#           origen sector  cveentuni           entidad            delega                    unidad               fechreg      sexo           entresi  cventine mpioresi  cvemuni  locresi  cvelocal     tipacien                evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind     ocupacio          seringre              fecingre              fecinisi                                   diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo conanima vacunado fecvaest tommue                                   labora  follabor    resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  viaje4  viaje5 antigencovid  \
# ...

# %% [markdown]
# Con la siguiente línea de código deberíamos poder ser capaces de eliminar la parte 'T00:00:00Z' del formato de fechas en la columna "fecinisi", esto tendrá utilidad para ser más estética la presentación de los datos en la gráfica final.

# %%
casos_CDMX_mar_jul_20_21_solo_del['fecinisi'] = casos_CDMX_mar_jul_20_21_solo_del['fecinisi'].map(lambda x: x.rstrip('T00:00:00Z'))

# %% [markdown]
# Corroboramos que la línea de código anterior funcione correctamente al verse modificado el formato de la fecha en la columna "fecinisi":

# %%
casos_CDMX_mar_jul_20_21_solo_del["fecinisi"][0]
# Out:
# '2020-10-22'

# %%
#casos_CDMX_mar_jul_20_21_solo_del["fecinisi"]=pd.to_datetime(casos_CDMX_mar_jul_20_21_solo_del["fecinisi"])

# %% [markdown]
# Ordenamos el data set por fecha:

# %%
casos_CDMX_mar_jul_20_21_solo_del_sort=casos_CDMX_mar_jul_20_21_solo_del.sort_values(["fecinisi"])

# %%
del casos_CDMX_mar_jul_20_21_solo_del

# %%
casos_CDMX_mar_jul_20_21_solo_del_sort.head(1)
# Out:
#        origen sector  cveentuni           entidad            delega                        unidad               fechreg      sexo           entresi  cventine mpioresi  cvemuni  locresi  cvelocal     tipacien                evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind     ocupacio          seringre              fecingre    fecinisi                         diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi     antivira fecinitxantivi conocaso contaves concerdo conanima vacunado fecvaest tommue labora  follabor resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  viaje4  viaje5 antigencovid   fecha_actualizacion
# ...

# %%
casos_CDMX_mar_jul_20_21_solo_del_sort.tail(1)
# Out:
#                 origen sector  cveentuni           entidad            delega        unidad               fechreg      sexo           entresi  cventine mpioresi  cvemuni             locresi  cvelocal     tipacien                evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind ocupacio          seringre              fecingre    fecinisi                         diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi antivira fecinitxantivi conocaso contaves concerdo conanima vacunado fecvaest tommue labora  follabor  resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  viaje4  viaje5 antigencovid   fecha_actualizacion
# ...

# %% [markdown]
# Como se puede observar, solo se pudieron rescatar datos desde el 6 de marzo de 2020 al 2 de julio de 2021. Aún así solo harían falta los registros del 1 de marzo al 5 de marzo, pero al no ser tantos días, resulta irrelevante esta ausencia de datos.

# %% [markdown]
# ### Filtro con solo los casos positivos

# %%
casos_CDMX_mar_jul_20_21_solo_del_sort["fecinisi"] = casos_CDMX_mar_jul_20_21_solo_del_sort["fecinisi"].replace({'00:00:00+00:00':''}, regex=True)

# %%
casos_CDMX_mar_jul_20_21_solo_del_sort.head(1)
# Out:
#        origen sector  cveentuni           entidad            delega                        unidad               fechreg      sexo           entresi  cventine mpioresi  cvemuni  locresi  cvelocal     tipacien                evoluci fecdef  semdef intubado digcline  edad   naciona estaemba  mesesemb esindige hableind     ocupacio          seringre              fecingre    fecinisi                         diagprob fiebre tos odinogia disnea irritabi diarrea dotoraci calofrios cefalea mialgias artral ataedoge rinorrea polipnea vomito dolabdo conjun cianosis inisubis diabetes epoc asma inmusupr hiperten vih_sida otracon enfcardi obesidad insrencr tabaquis rectrata txcrobia txantivi     antivira fecinitxantivi conocaso contaves concerdo conanima vacunado fecvaest tommue labora  follabor resdefin esmigra paisnal  paisori  fingmex puerperio  diaspuerp antipireticos  uci  linaje viaje1  viaje2  viaje3  viaje4  viaje5 antigencovid   fecha_actualizacion
# ...

# %%
resdefin_SARS_CoV_2 = casos_CDMX_mar_jul_20_21_solo_del_sort['resdefin'] == "SARS-CoV-2"

# %%
casos_CDMX_mar_jul__20_21_positivos_CoV_19 = casos_CDMX_mar_jul_20_21_solo_del_sort[resdefin_SARS_CoV_2]

# %%
casos_pos_ago_sep_20_21 =  casos_CDMX_mar_jul__20_21_positivos_CoV_19 .groupby(["fecinisi","resdefin"]).size()
casos_pos_ago_sep_20_21
# Out:
# fecinisi    resdefin
# 2020-03-02  SARS-CoV-2       3
# 2020-03-03  SARS-CoV-2       3
# 2020-03-04  SARS-CoV-2       3
# 2020-03-06  SARS-CoV-2       5
# 2020-03-07  SARS-CoV-2       8
# 2020-03-08  SARS-CoV-2       5
# 2020-03-09  SARS-CoV-2      16
# 2020-03-1   SARS-CoV-2      21
# 2020-03-11  SARS-CoV-2      21
# 2020-03-12  SARS-CoV-2      15
# 2020-03-13  SARS-CoV-2      30
# 2020-03-14  SARS-CoV-2      30
# 2020-03-15  SARS-CoV-2      32
# 2020-03-16  SARS-CoV-2      35
# 2020-03-17  SARS-CoV-2      22
# 2020-03-18  SARS-CoV-2      22
# 2020-03-19  SARS-CoV-2      30
# 2020-03-2   SARS-CoV-2      50
# 2020-03-21  SARS-CoV-2      18
# 2020-03-22  SARS-CoV-2      25
# 2020-03-23  SARS-CoV-2      44
# 2020-03-24  SARS-CoV-2      39
# 2020-03-25  SARS-CoV-2      44
# 2020-03-26  SARS-CoV-2      72
# 2020-03-27  SARS-CoV-2      54
# 2020-03-28  SARS-CoV-2      57
# 2020-03-29  SARS-CoV-2      48
# 2020-03-3   SARS-CoV-2      97
# 2020-03-31  SARS-CoV-2      72
# ...

# %%
type(casos_pos_ago_sep_20_21)
# Out:
# pandas.core.series.Series

# %%
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

# %%
sns.set(rc={'figure.figsize':(15.7,10.27)})
fig, ax = plt.subplots(figsize=(15, 15))
casos_pos_ago_sep_20_21.plot(kind='area',xlabel='fecinisi')
ax.set(xlabel="Fecha",
       ylabel="Casos Positivos a SARS-CoV-2",
       title="Historial de casos positivos diarios desde 2020-03-01 al 2021-07-02 (AA/MM/DD)",
       )




plt.show()

# %% [markdown]
# fecha_inicial = '2020-03-01T00:00:00Z'
# fecha_final = '2021-07-02T00:00:00Z'
